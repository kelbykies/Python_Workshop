# %% [markdown]
# # Exercise Solutions
# ## Exercise #1:

# %%
#1:
x =4
#2:
x = x + 100
#3:
x = x/4.5
#4:
x = x - 10
#5:
x = x * 2
#6:
print(x)
# Out:
# 26.22222222222222

# %%
# Bonus
x = 4
((x + 100)/4.5 - 10) * 2
# Out:
# 26.22222222222222

# %% [markdown]
# ## Exercise #2:

# %%
# 1: Make a list of your 3 favorite foods and assign to a variable called `food`.
# Print. your list using the variable name.
food = ['pizza', 'pancakes', 'pears']
print(food)
# Out:
# ['pizza', 'pancakes', 'pears']

# %%
#2:Now add your 1 of your neighbor's favorite foods to your list using append. 
# For those of you that are virtual feel free to type a food in the chat or add my favorite food `'chocolate'.
# Print your updated list.

food.append('chocolate')
print(food)
# Out:
# ['pizza', 'pancakes', 'pears', 'chocolate']

# %%
food[3]
# Out:
# 'chocolate'

# %%
food[3][4]
# Out:
# 'o'

# %%
#3: Create a dictionary with the key's food, hobby, subject.
# Assign each key your favorite. Call this dictionary `favorites`.
favorites = {'food':'chocolate',
            'hobby':'arts/crafts',
            'subject':'biology'}
print(favorites)
# Out:
# {'food': 'chocolate', 'hobby': 'arts/crafts', 'subject': 'biology'}

# %%
favorites['sport'] = 'swimming'
print(favorites)
# Out:
# {'food': 'chocolate', 'hobby': 'arts/crafts', 'subject': 'biology', 'sport': 'swimming'}

# %% [markdown]
# ## Exercise #3

# %%
#1. Using the Chihuahuan Desert ecosystem make a line plot comparing the hindfoot length of M/F over time.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


# Import surveys_complete.csv
surveys = pd.read_csv('data/surveys_complete.csv', index_col=0)

sns.lineplot(data=surveys, x='year', y='hindfoot_length', hue='sex').set(title='Hindfoot Length from 1977-2002')
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
#2. Make a Box plot summary of weights for each plot using the column `plot_id`.

ax = sns.boxplot(x="plot_id", y="weight", data=surveys)
# Set the title of the plot
ax.set_title('Summary of Life Expectancy for 15 Countries over 217 Years')
# Rotate the labels on the x-axis for better readability
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, '1'),
#  Text(1, 0, '2'),
#  Text(2, 0, '3'),
#  Text(3, 0, '4'),
#  Text(4, 0, '5'),
#  Text(5, 0, '6'),
#  Text(6, 0, '7'),
#  Text(7, 0, '8'),
#  Text(8, 0, '9'),
#  Text(9, 0, '10'),
#  Text(10, 0, '11'),
#  Text(11, 0, '12'),
#  Text(12, 0, '13'),
#  Text(13, 0, '14'),
#  Text(14, 0, '15'),
#  Text(15, 0, '16'),
#  Text(16, 0, '17'),
#  Text(17, 0, '18'),
#  Text(18, 0, '19'),
#  Text(19, 0, '20'),
#  Text(20, 0, '21'),
#  Text(21, 0, '22'),
#  Text(22, 0, '23'),
#  Text(23, 0, '24')]
